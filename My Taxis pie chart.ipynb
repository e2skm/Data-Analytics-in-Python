# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
taxis = [30,15,20,15,10,5,5]

# %%
labels = ['Quantum','Iveco','Siyaya','Microbus','Avanza','Yaris','Broken']

# %%
colors = ['gold','lightblue','pink','purple','y','r','orange']

# %%
plt.figure(figsize=(14,6))
plt.pie(taxis, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('My Taxis')
# Out:
# Text(0.5, 1.0, 'My Taxis')
